# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import display
from IPython.html.widgets import interact
from py_ks import *

# %%
# load data
f = h5py.File('../../data/myN32/ks22h02t100EV.h5', 'r');

dataName1 = '/ppo/2/';
a1 = f[dataName1 + 'a'].value;
T1 = f[dataName1 + 'T'].value[0]; 
nstp1 = np.int(f[dataName1 + 'nstp'].value[0]);
h1 = T1 / nstp1;
e1 = f[dataName1 + 'e'].value;

dataName2 = '/rpo/1/';
a2 = f[dataName2 + 'a'].value;
T2 = f[dataName2 + 'T'].value[0]; 
nstp2 = np.int(f[dataName2 + 'nstp'].value[0]);
h2 = T2 / nstp2;
e2 = f[dataName2 + 'e'].value;

# print h, T, a0
ks1 = pyKS(32, h1, 22);
aa1 = ks1.intg(a1, nstp1, 1); aaWhole1 = ks1.half2whole(aa1[:-1, :]); print aaWhole1.shape
aaHat1, ang = ks.orbitToSlice(aaWhole1);

ks2 = pyKS(32, h2, 22);
aa2 = ks2.intg(a2, nstp2, 1); 
aaHat2, ang2 = ks.orbitToSlice(aa2);

# print e1, e2
# Out:
# (1440, 30)

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')
#ax.plot(aaWhole[:, 0], aaWhole[:, 1], aaWhole[:, 2])
ax.plot(aaHat1[:, 0], aaHat1[:, 2], aaHat1[:, 3], 'r')
ax.plot(aaHat2[:, 0], aaHat2[:, 2], aaHat2[:, 3], 'g')
@interact(elev=(-90, 90), azim=(0, 360))
def view(elev, azim):
    ax.view_init(elev, azim)
    display(ax.figure)

# %%
ve = np.array(f['/ppo/1/ve']).T;
N, M = ve.shape; N = np.int(np.sqrt(N));
ve = ve[:,0]; ve.resize(N, N);
